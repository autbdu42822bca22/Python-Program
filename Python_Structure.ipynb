# %% [markdown]
# ### 1.List
# ### -1D
# ### -heterogenous
# ### -indexing and slicing is possible
# ### -mutable

# %%
empty_card=[]
empty_card
# Out:
# []

# %%
type(empty_card)
# Out:
# list

# %%
item_to_list=["apple","orange","banana","mango",12,3,4.0]
item_to_list
# Out:
# ['apple', 'orange', 'banana', 'mango', 12, 3, 4.0]

# %%
type(item_to_list)
# Out:
# list

# %%
item_to_list=["apple","orange","banana","mango",12,3,4.0]
item_to_list
# Out:
# ['apple', 'orange', 'banana', 'mango', 12, 3, 4.0]

# %%
item_to_list=["apple","orange","banana","mango",12,3,4.0,"apple"]
item_to_list
# Out:
# ['apple', 'orange', 'banana', 'mango', 12, 3, 4.0, 'apple']

# %%
item_to_list[0]
# Out:
# 'apple'

# %%
item_to_list[0:4]
# Out:
# ['apple', 'orange', 'banana', 'mango']

# %%
item_to_list[-4:-1]
# Out:
# [12, 3, 4.0]

# %%
len(item_to_list)
# Out:
# 8

# %%
item_to_list[1]="watermelon"
item_to_list
# Out:
# ['apple', 'watermelon', 'banana', 'mango', 12, 3, 4.0, 'apple']

# %%
item_to_list.append("orange")
item_to_list
# Out:
# ['apple', 'watermelon', 'banana', 'mango', 12, 3, 4.0, 'apple', 'orange']

# %%
item_to_list.copy()
# Out:
# ['apple', 'watermelon', 'banana', 'mango', 12, 3, 4.0, 'apple', 'orange']

# %%
item_to_list.count("apple")
# Out:
# 2

# %%
item_to_list.index("apple")
# Out:
# 0

# %%
item_to_list.pop(-1)
# Out:
# 'orange'

# %%
item_to_list.remove("apple")
item_to_list
# Out:
# ['Grapes', 'watermelon', 'banana', 'mango', 12, 3, 4.0]

# %% [markdown]
# ### 2.Set
# #### -1D
# #### -heterogenous
# #### -it won't allow duplicate value
# #### -indexing and slicing is not possible
# #### -mutable

# %%
empty_card_2 = set()
empty_card_2
# Out:
# set()

# %%
type(empty_card_2)
# Out:
# set

# %%
item_to_set={"apple","orange","banana","mango",12,3,4.0}
item_to_set
# Out:
# {12, 3, 4.0, 'apple', 'banana', 'mango', 'orange'}

# %%
type(item_to_set)
# Out:
# set

# %%
item_to_set={"apple","orange","banana","mango",12,3,4.0,"apple"}
item_to_set
# Out:
# {12, 3, 4.0, 'apple', 'banana', 'mango', 'orange'}

# %%
item_to_set[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 item_to_set[1]
#
# TypeError: 'set' object is not subscriptable

# %%
item_to_set
# Out:
# {12, 3, 4.0, 'apple', 'banana', 'mango', 'orange'}

# %%
item_to_set[1] = "watermelon"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 item_to_set[1] = "watermelon"
#
# TypeError: 'set' object does not support item assignment

# %%
item_to_set.add("watermelon")

# %%
item_to_set
# Out:
# {12, 3, 4.0, 'apple', 'banana', 'mango', 'orange', 'watermelon'}

# %%
item_to_set.discard("apple")

# %%
item_to_set
# Out:
# {12, 3, 4.0, 'banana', 'mango', 'orange', 'watermelon'}

# %%
item_to_set.union("apple")
# Out:
# {12, 3, 4.0, 'a', 'banana', 'e', 'l', 'mango', 'orange', 'p', 'watermelon'}

# %%
item_to_set.update("melon")
item_to_set
# Out:
# {12,
#  3,
#  4.0,
#  'banana',
#  'e',
#  'l',
#  'm',
#  'mango',
#  'n',
#  'o',
#  'orange',
#  'watermelon'}

# %% [markdown]
# ### Tuple
# #### -1D
# #### -Heterogenous
# #### -duplicate values is allowed
# #### -immutable
# #### -indexing and slicing is also possible

# %%
empty_card_3=()
empty_card_3
# Out:
# ()

# %%
type(empty_card_3)
# Out:
# tuple

# %%
item_to_tuple=("apple","orange","banana","mango",12,3,4.5)
item_to_tuple
# Out:
# ('apple', 'orange', 'banana', 'mango', 12, 3, 4.5)

# %%
type(item_to_tuple)
# Out:
# tuple

# %%
item_to_tuple=("apple","orange","banana","mango",12,3,4.5,"apple")
item_to_tuple
# Out:
# ('apple', 'orange', 'banana', 'mango', 12, 3, 4.5, 'apple')

# %%
item_to_tuple[1]
# Out:
# 'orange'

# %%
item_to_tuple[-4:-2]
# Out:
# (12, 3)

# %%
item_to_tuple[1]="Water"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 item_to_tuple[1]="Water"
#
# TypeError: 'tuple' object does not support item assignment

# %%
item_to_tuple.count("apple")
# Out:
# 2

# %%
item_to_tuple.index("apple")
# Out:
# 0

# %% [markdown]
# ### 4.Dictionary
#
# It is a key:value pair
# #### -2D
# #### -indexig and slicing is not possible
# #### -heterogenous
# #### -mutable
# #### - Don't create duplicate a key,but you can create deplicate value

# %%
empty_card_4 ={}

# %%
empty_card_4
# Out:
# {}

# %%
type(empty_card_4)
# Out:
# dict

# %%
item_to_dict={"apple":2,"orange":5,"banana":3,"mango":4}
item_to_dict
# Out:
# {'apple': 2, 'orange': 5, 'banana': 3, 'mango': 4}

# %%
type(item_to_dict)
# Out:
# dict

# %%
item_to_dict={"apple":2,"orange":5,"banana":3,"mango":4,"apple":5}
item_to_dict
# Out:
# {'apple': 5, 'orange': 5, 'banana': 3, 'mango': 4}

# %%
item_to_dict[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 item_to_dict[1]
#
# KeyError: 1

# %%
item_to_dict.clear()

# %%
item_to_dict
# Out:
# {'apple': 5, 'orange': 5, 'banana': 3, 'mango': 4}

# %%
item_to_dict.keys()
# Out:
# dict_keys(['apple', 'orange', 'banana', 'mango'])

# %%
item_to_dict.values()
# Out:
# dict_values([5, 5, 3, 4])

# %%
item_to_dict={"apple":2,"orange":5,"banana":3,"mango":4,"apple":5}
item_to_dict
# Out:
# {'apple': 5, 'orange': 5, 'banana': 3, 'mango': 4}

# %%
import pandas as pd

# %%
pd.DataFrame(data=item_to_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 pd.DataFrame(data=item_to_dict)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
math_student_mark={"Name":["Priya","Mohana","Mohanapriya","Soundharya"],
                   "Math":[67,88,99,100],"Science":[100,78,99,98]}
math_student_mark
# Out:
# {'Name': ['Priya', 'Mohana', 'Mohanapriya', 'Soundharya'],
#  'Math': [67, 88, 99, 100],
#  'Science': [100, 78, 99, 98]}

# %%
import pandas as pd

# %%
pd.DataFrame(data=math_student_mark)
# Out:
#           Name  Math  Science
# 0        Priya    67      100
# 1       Mohana    88       78
# 2  Mohanapriya    99       99
# 3   Soundharya   100       98

# %%
math_student_mark={"Priya","Mohana","Mohanapriya","Soundharya"}
                
math_student_mark
# Out:
# {'Mohana', 'Mohanapriya', 'Priya', 'Soundharya'}

# %%
pd.DataFrame(data=math_student_mark)
# Out:
#              0
# 0       Mohana
# 1        Priya
# 2   Soundharya
# 3  Mohanapriya

# %%
math_student_mark=("Priya","Mohana","Mohanapriya","Soundharya")
                
math_student_mark
# Out:
# ('Priya', 'Mohana', 'Mohanapriya', 'Soundharya')

# %%
pd.DataFrame(data=math_student_mark)
# Out:
#              0
# 0        Priya
# 1       Mohana
# 2  Mohanapriya
# 3   Soundharya
